# %% [markdown]
# ## 1. Importar librerias

# %%
#from sklearn.datasets import fetch_20newsgroups
import pandas as pd
import os
import unidecode
import pickle
import matplotlib.pyplot as plt
from wordcloud import*
import numpy as np
from PIL import Image
import random
import datetime

import spacy
nlp = spacy.load('es_core_news_sm')

## 2. Importar base SS

# %% [markdown]
# ## 2. Importar base SS

# %%
# create an empty pandas data frame
df = pd.DataFrame()
 
# iterate over all files within "My_Folder"
for file in os.listdir("social_studio"):
    if file.endswith(".csv"):
        df = pd.concat([df , pd.read_csv(os.path.join("social_studio", file))], axis=0 )
 
# reset the index 
df.reset_index(drop=True, inplace=True)
df = df.drop_duplicates(keep='first')
df=df.drop(df.columns[[0, 1]], axis=1) 
df.to_csv('ss_completo.csv')

# %%
df.shape
# Out:
# (17983, 23)

# %% [markdown]
# ## 3. Procesamiento base ss

# %%
tablacomments=df

# %%
# Convierte a tipo fecha la columna PUBLISH_DATE
tablacomments["PUBLISH_DATE"]=pd.to_datetime(tablacomments["PUBLISH_DATE"])
# Selecciona columnas de interés, filtra el contenido, da formato a la decha y pone en minúsculas la columna 'CONTENT'. Finalmente imprime la base de datos:
TABLACONTENT= tablacomments[["CONTENT", "REGION", "FOLLOWERS", "PUBLISH_DATE", "AUTHOR",'ARTICLE_URL']]
TABLACONTENT= TABLACONTENT[(~TABLACONTENT["CONTENT"].isna())&(TABLACONTENT["CONTENT"]!="Content not available" )]
TABLACONTENT["FECHA"]=TABLACONTENT["PUBLISH_DATE"].dt.strftime("%m/%d/%Y")
TABLACONTENT['CONTENT'] = TABLACONTENT['CONTENT'].str.lower()

#Normalizar contenido
TABLACONTENT['CONTENT_']=TABLACONTENT['CONTENT'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').copy()
#TABLACONTENT['PUBLISH_DATE'].unique()

# %%
#Filtro fecha
TABLACONTENT_Marzo = TABLACONTENT[TABLACONTENT["PUBLISH_DATE"] >='2021-03-01T04:36:24.000000000']
TABLACONTENT = TABLACONTENT_Marzo
#TABLACONTENT = TABLACONTENT.drop_duplicates(subset='CONTENT_', keep='first')
TABLACONTENT.shape
# Out:
# (5176, 8)

# %%
#################### MODIFICAR (opcional) ####################
palabra = 'dob'
prueba = TABLACONTENT.loc[TABLACONTENT['CONTENT'].str.contains(palabra),['CONTENT','AUTHOR','FECHA']]#
prueba.CONTENT.count()
# Out:
# 67

# %%
# Quita los textos que contienen estas palabras (usar con cuidado)

PALABRAS_FILTRO = [
                  ]

TABLACONTENT = TABLACONTENT[~TABLACONTENT.CONTENT.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
TABLACONTENT.shape
# Out:
# (5176, 8)

# %% [markdown]
# ## 4. Filtro por procesos

# %% [markdown]
# ### 4.1. Consumo

# %% [markdown]
# #### 4.1.1. Wordcloud general

# %%
# Contar cant de tweets asociados al filtro

PALABRAS_FILTRO = [ 'lectura', 'consumo', 'doble', 'errada', 'regist'
                  ]

df_consumo = TABLACONTENT[TABLACONTENT.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_consumo=df_consumo.drop_duplicates(subset='CONTENT_', keep='first')


#filtro por proceso
searchfor=['consumo', 'lectura', 'errada', 'doble', 'regist' ]

texto_consumo=''.join(df_consumo[df_consumo.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_consumo.CONTENT.count()
# Out:
# 320

# %%
PALABRAS_FILTRO = [ 'dobl'
                  ]

df_suspencion_= df_consumo[df_consumo.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_RPO=df_RPO.drop_duplicates(subset='CONTENT_', keep='first')


df_suspencion_['CONTENT'].count()
# Out:
# 39

# %%
#lematizar
text = texto_consumo
doc = nlp(text)
lemmas = [tok.lemma_.lower() for tok in doc]

# %%
#pasar de lista a str
texto_consumo_ = ' '.join([str(elem) for elem in lemmas])

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('HTTPS')
stop_words.append('t')
stop_words.append('ga')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('poder')

sw=set(STOPWORDS)
sw=stop_words

# %%
wc=WordCloud(collocations=True,
             collocation_threshold=10,
            stopwords=sw,
              background_color='white',
              width=1500,
              height=800,
              max_words=80,
             colormap='Dark2',
                    ).generate(texto_consumo_)

fig, axes = plt.subplots(1, 1, figsize=(20,20), sharex=True, sharey=True)

plt.gca().imshow(wc)
plt.gca().set_title('Topic Global', fontdict=dict(size=16))
plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.savefig('raspones_Wc.png')
plt.show()

# %% [markdown]
# #### 4.1.2. Bigramas

# %%
#bigramas

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
texto_consumo_big=df_consumo['CONTENT_'].unique().tolist()
texto_consumo_big[0]
# Out:
# 'una pregunta para el @grupovanti: si son tan eficientes para verificar la falta de pago de una factura y programar la suspension del servicio, por que no pueden registrar el pago y programar la reconexion?  no es un abuso? @sicsuper @superservicios'

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('https')
stop_words.append('HTTPS')
stop_words.append('CO')
stop_words.append('@')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('poder')

# %%
def lemmatize_stemming(text):
    #return stemmer.stem(text)
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    texto_vanti_ = ' '.join([str(elem) for elem in lemmas])
    return texto_vanti_


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_words and len(token) > 2:
            result.append(lemmatize_stemming(token))
           
            #result.append((token))
            
    return result

# %%
processed_docs = []

for doc in texto_consumo_big:
    processed_docs.append(preprocess(doc))

# %%
processed_docs[0]
# Out:
# ['preguntar',
#  'grupovanti',
#  'tanto',
#  'eficient',
#  'verificar',
#  'falta',
#  'pago',
#  'factura',
#  'programar',
#  'suspension',
#  'servicio',
#  'poder',
#  'registrar',
#  'pago',
#  'programar',
#  'reconexion',
#  'abuso',
#  'sicsuper',
#  'superservicio']

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in processed_docs]

# View bigrams for the first tweet
terms_bigram[0]
# Out:
# [('preguntar', 'grupovanti'),
#  ('grupovanti', 'tanto'),
#  ('tanto', 'eficient'),
#  ('eficient', 'verificar'),
#  ('verificar', 'falta'),
#  ('falta', 'pago'),
#  ('pago', 'factura'),
#  ('factura', 'programar'),
#  ('programar', 'suspension'),
#  ('suspension', 'servicio'),
#  ('servicio', 'poder'),
#  ('poder', 'registrar'),
#  ('registrar', 'pago'),
#  ('pago', 'programar'),
#  ('programar', 'reconexion'),
#  ('reconexion', 'abuso'),
#  ('abuso', 'sicsuper'),
#  ('sicsuper', 'superservicio')]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)
# Out:
# [(('atencion', 'usuario'), 26),
#  (('canal', 'oficial'), 24),
#  (('oficial', 'atencion'), 24),
#  (('estar', 'cobrar'), 20),
#  (('grupovanti', 'hola'), 18),
#  (('gas', 'natural'), 15),
#  (('cobrar', 'doble'), 15),
#  (('delegado', 'proteccion'), 13),
#  (('proteccion', 'usuario'), 13),
#  (('usuario', 'gestion'), 13),
#  (('gestion', 'territorio'), 13),
#  (('territorio', 'podra'), 13),
#  (('registrar él', 'canal'), 12),
#  (('podra', 'seguimiento'), 12),
#  (('grupovanti', 'superservicio'), 11),
#  (('invitamos', 'registrar él'), 11),
#  (('atender', 'oportunamente'), 11),
#  (('oportunamente', 'caso'), 11),
#  (('doble', 'factura'), 10),
#  (('factura', 'ladronesvanti'), 10)]

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(15),
                             columns=['bigram', 'count'])
bigram_df['bigram']=bigram_df['bigram'].astype(str)
bigram=list((bigram_df['bigram']))
count=list((bigram_df['count']))

# %%
df = bigram_df.iloc[::-1]

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

plt.barh(bigram, count, align='center', alpha=0.5, color='purple')
#plt.yticks(y_pos, )
plt.xlabel('Frecuencia')
plt.title('Frecuencia de bigramas para consumo')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 4.1.3 n-grams, principales narrativas

# %%
# import necessary libraries

import re, string
from nltk.corpus import stopwords
import nltk

df = df_consumo.drop_duplicates(subset='CONTENT_', keep='first')
nlp = spacy.load('es_core_news_sm') # español 
def normalize(text):
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    lemmas=" ".join(lemmas)
    doc1 = nlp(lemmas)
    words = [t.orth_ for t in doc1 if not t.is_punct ]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    return lexical_tokens


# list contains  punctuation
sw_list = stopwords.words('spanish')
sw_list.append('oficiales')
sw_list += list(string.punctuation)
sw_list = []
sw_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'", '©',
'@', '-', '–','--','—', '_','!!','¡¡','¿','?','!','¡','.co','http ','#','http',':','//']
sw_set = set(sw_list)

# tokenization
def process_data(string):
    tokens = nltk.word_tokenize(string) # tokenization
    punctuation_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    punctuation_removed = [token.lower() for token in tokens ]
    return punctuation_removed

# create a function stemming() and loop through each word in a review
def stemming(string):
    # Stemming
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_string=[]
    for w in string:
        stemmed_string.append(ps.stem(w))
    return stemmed_string


# create a function  and loop through each word in  a review
def lemmatization(string):
    # import libraries
    from nltk.stem.wordnet import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma_list=[]
    for word in string:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Conbime all functions above and obtian cleaned text data 
def data_preprocessing(text_data):
    ##tokenization, stop words removal, punctuation marks removel
    processed_string=list(map(process_data,text_data))
    #stemming
    # stemming_string=list(map(stemming,processed_string)) #Data out prurals 
    ## lemmatization
    lemma_string=list(map(lemmatization,processed_string))
    
    return lemma_string

cleaned_data = data_preprocessing(df['CONTENT'])
merged_data=[]
for i in range(len(cleaned_data )):
    merged_data.append(" ".join(cleaned_data [i]))
merged_df=pd.DataFrame(merged_data)
merged_df.to_csv("merged_df.csv")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      82                 try:
# ---> 83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\mateo.galvis/nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-47-5df87ae4bca9> in <module>
#      66     return lemma_string
#      67
# ---> 68 cleaned_data = data_preprocessing(df['CONTENT'])
#      69 merged_data=[]
#      70 for i in range(len(cleaned_data )):
#
# <ipython-input-47-5df87ae4bca9> in data_preprocessing(text_data)
#      62     # stemming_string=list(map(stemming,processed_string)) #Data out prurals
#      63     ## lemmatization
# ---> 64     lemma_string=list(map(lemmatization,processed_string))
#      65
#      66     return lemma_string
#
# <ipython-input-47-5df87ae4bca9> in lemmatization(string)
#      51     lemma_list=[]
#      52     for word in string:
# ---> 53         lemma_word=lemmatizer.lemmatize(word,pos='v')
#      54         lemma_list.append(lemma_word)
#      55     return lemma_list
#
# ~\Anaconda3\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      36
#      37     def lemmatize(self, word, pos=NOUN):
# ---> 38         lemmas = wordnet._morphy(word, pos)
#      39         return min(lemmas, key=len) if lemmas else word
#      40
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     118             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     119
# --> 120         self.__load()
#     121         # This looks circular, but its not, since __load() changes our
#     122         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
# ---> 85                     raise e
#      86
#      87         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      78         else:
#      79             try:
# ---> 80                 root = nltk.data.find("{}/{}".format(self.subdir, self.__name))
#      81             except LookupError as e:
#      82                 try:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\mateo.galvis/nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\mateo.galvis\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
# obtener los ngrams  
def get_top_n_bigram(corpus, n=None):
    from sklearn.feature_extraction.text import CountVectorizer
    vec = CountVectorizer(ngram_range=(4, 6)).fit(corpus) # minimo y maximo de palabras 
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def bigram_dictionary(data,n=None):
    # n es la cantidad de n_grams que se desean adquirir 
    words_freq=get_top_n_bigram(data,n)
    
    dictionary={}
    for i in range(len(words_freq)):
        dictionary[words_freq[i][0]]=words_freq[i][1]
    return dictionary

BOW = bigram_dictionary(merged_data,510)# get top (merged_data,n= )
BOW

# %%
# Nos quedamos con el BAG que tengan un umbral de similitud de 0.3 (no se parezcan ) 
# y con la frase más larga  
sentences = []
BOW_new = {}
for key0,value0 in BOW.items():
    same = [ key for key,value in BOW.items() if value0==value]
    max_same = max(same)
    same_similarity = [s for s in same if nlp(s).similarity(nlp(max_same))<=0.3] + [max_same] #0.45 Umbral de similitud 
    sentences.append(same_similarity)
    frases = []
    for s in range(len(sentences)):
        lista = list(map(len,sentences[s]))
        try:
            maxi = max(lista)
            frases.append(sentences[s][lista.index(maxi)])
            frases.append(sentences[s][-1])
        except:
            continue 
            
for i in list(dict.fromkeys(frases)):
    BOW_new[i] = BOW[i]

# %%
# from PIL import Image
# twitter_mask = np.array(Image.open('./twitter_mask.png'))
cloud = WordCloud(background_color='white',
                  width=1500,
                  height=800,
                  colormap='tab10',
                  max_words=50,
                  prefer_horizontal=1.0
                 )
                  
plt.figure(figsize=(10,10), facecolor='w')
Wcloud = cloud.generate_from_frequencies(BOW_new, max_font_size=800)
plt.gca().imshow(Wcloud)
plt.gca().set_title('Principales narrativas', fontdict=dict(size=16))
plt.gca().axis('off')
plt.show()

# %% [markdown]
# ### 4.2. RPO

# %% [markdown]
# #### 4.2.1. Wordcloud general

# %%
# Contar cant de tweets asociados al filtro

PALABRAS_FILTRO = [ 'RPO', 'obligatoria','revisión','revision', 'anual'
                  ]

df_RPO = TABLACONTENT[TABLACONTENT.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_RPO=df_RPO.drop_duplicates(subset='CONTENT_', keep='first')

#filtro por proceso
searchfor=['RPO', 'obligatoria', 'revisión','revision', 'anual']

texto_RPO=''.join(df_RPO[df_RPO.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_RPO['CONTENT'].count()

# %%
PALABRAS_FILTRO = [ 'el tecnico', 'operario','operador','visita',
                  ]

df_RPO = df_RPO[df_RPO.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_RPO=df_RPO.drop_duplicates(subset='CONTENT_', keep='first')

texto_RPO=''.join(df_RPO[df_RPO.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_RPO['CONTENT'].count()

# %%
PALABRAS_FILTRO = [ 'etica']

df_RPO_filtr = df_RPO[df_RPO.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
df_RPO_filtr.CONTENT_.unique()

# %%
498/1319

# %%
#lematizar
text = texto_RPO
doc = nlp(text)
lemmas = [tok.lemma_.lower() for tok in doc]

# %%
#pasar de lista a str
texto_RPO_ = ' '.join([str(elem) for elem in lemmas])

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('HTTPS')
stop_words.append('t')
stop_words.append('si')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('ma')
stop_words.append('poder')

sw=set(STOPWORDS)
sw=stop_words

# %%
wc=WordCloud(collocations=True,
             collocation_threshold=10,
            stopwords=sw,
              background_color='white',
              width=1500,
              height=800,
              max_words=80,
             colormap='Dark2',
                    ).generate(texto_RPO_)
fig, axes = plt.subplots(1, 1, figsize=(20,20), sharex=True, sharey=True)

plt.gca().imshow(wc)
plt.gca().set_title('Topic Global', fontdict=dict(size=16))
plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.2.2. Bigramas

# %%
#bigramas
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
texto_RPO_big=df_RPO['CONTENT_'].unique().tolist()
texto_RPO_big[0]

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('https')
stop_words.append('HTTPS')
stop_words.append('CO')

# %%
def lemmatize_stemming(text):
    #return stemmer.stem(text)
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    texto_vanti_ = ' '.join([str(elem) for elem in lemmas])
    return texto_vanti_


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_words and len(token) > 2:
            result.append(lemmatize_stemming(token))
           
            #result.append((token))
            
    return result

# %%
processed_docs = []

for doc in texto_RPO_big:
    processed_docs.append(preprocess(doc))

# %%
processed_docs[0]

# %%
# Create list of lists containing bigrams in tweets
terms_bigram_ = [list(bigrams(tweet)) for tweet in processed_docs]

# View bigrams for the first tweet
terms_bigram_[0]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram_))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(15),
                             columns=['bigram', 'count'])

bigram_df['bigram']=bigram_df['bigram'].astype(str)
bigram=list((bigram_df['bigram']))
count=list((bigram_df['count']))

# %%
df = bigram_df.iloc[::-1]

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt



plt.barh(bigram, count, align='center', alpha=0.5, color='purple')
#plt.yticks(y_pos, )
plt.xlabel('Frecuencia')
plt.title('Frecuencia de bigramas para RPO')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 4.2.3. n-grams

# %%
import re, string
from nltk.corpus import stopwords
import nltk

df = df_RPO.drop_duplicates(subset='CONTENT_', keep='first')
nlp = spacy.load('es_core_news_sm') # español 
def normalize(text):
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    lemmas=" ".join(lemmas)
    doc1 = nlp(lemmas)
    words = [t.orth_ for t in doc1 if not t.is_punct ]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    return lexical_tokens


# list contains  punctuation
sw_list = stopwords.words('spanish')
sw_list += list(string.punctuation)
sw_list = []
sw_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'", '©',
'@', '-', '–','--','—', '_','!!','¡¡','¿','?','!','¡','.co','http ','#','http',':','//']
sw_set = set(sw_list)

# tokenization
def process_data(string):
    tokens = nltk.word_tokenize(string) # tokenization
    punctuation_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    punctuation_removed = [token.lower() for token in tokens ]
    return punctuation_removed

# create a function stemming() and loop through each word in a review
def stemming(string):
    # Stemming
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_string=[]
    for w in string:
        stemmed_string.append(ps.stem(w))
    return stemmed_string


# create a function  and loop through each word in  a review
def lemmatization(string):
    # import libraries
    from nltk.stem.wordnet import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma_list=[]
    for word in string:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Conbime all functions above and obtian cleaned text data 
def data_preprocessing(text_data):
    ##tokenization, stop words removal, punctuation marks removel
    processed_string=list(map(process_data,text_data))
    #stemming
    # stemming_string=list(map(stemming,processed_string)) #Data out prurals 
    ## lemmatization
    lemma_string=list(map(lemmatization,processed_string))
    
    return lemma_string

cleaned_data = data_preprocessing(df['CONTENT'])
merged_data=[]
for i in range(len(cleaned_data )):
    merged_data.append(" ".join(cleaned_data [i]))
merged_df=pd.DataFrame(merged_data)

# %%
# obtener los ngrams  
def get_top_n_bigram(corpus, n=None):
    from sklearn.feature_extraction.text import CountVectorizer
    vec = CountVectorizer(ngram_range=(4, 6)).fit(corpus) # minimo y maximo de palabras 
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def bigram_dictionary(data,n=None):
    # n es la cantidad de n_grams que se desean adquirir 
    words_freq=get_top_n_bigram(data,n)
    
    dictionary={}
    for i in range(len(words_freq)):
        dictionary[words_freq[i][0]]=words_freq[i][1]
    return dictionary

BOW = bigram_dictionary(merged_data,15)# get top (merged_data,n= )
BOW

# %%
# Nos quedamos con el BAG que tengan un umbral de similitud de 0.3 (no se parezcan ) 
# y con la frase más larga  
sentences = []
BOW_new = {}
for key0,value0 in BOW.items():
    same = [ key for key,value in BOW.items() if value0==value]
    max_same = max(same)
    same_similarity = [s for s in same if nlp(s).similarity(nlp(max_same))<=0.3] + [max_same] #0.45 Umbral de similitud 
    sentences.append(same_similarity)
    frases = []
    for s in range(len(sentences)):
        lista = list(map(len,sentences[s]))
        try:
            maxi = max(lista)
            frases.append(sentences[s][lista.index(maxi)])
            frases.append(sentences[s][-1])
        except:
            continue 
            
for i in list(dict.fromkeys(frases)):
    BOW_new[i] = BOW[i]

# %%
# from PIL import Image
# twitter_mask = np.array(Image.open('./twitter_mask.png'))
cloud = WordCloud(background_color='white',
                  width=1500,
                  height=800,
                  colormap='tab10',
                  max_words=50,
                  prefer_horizontal=1.0
                 )
                  
plt.figure(figsize=(10,10), facecolor='w')
Wcloud = cloud.generate_from_frequencies(BOW_new, max_font_size=800)
plt.gca().imshow(Wcloud)
plt.gca().set_title('Principales narrativas', fontdict=dict(size=16))
plt.gca().axis('off')
plt.show()

# %% [markdown]
# ### 4.3. Suspención

# %% [markdown]
# #### 4.3.1. Wordcloud general

# %%
# Contar cant de tweets asociados al filtro

PALABRAS_FILTRO = [ 'susp', 'corta', 'fecha', 'limite'
                  ]

df_suspencion = TABLACONTENT[TABLACONTENT.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_consumo=df_consumo.drop_duplicates(subset='CONTENT_', keep='first')


#filtro por proceso
searchfor=['susp' , 'corta', 'fecha', 'limite']

texto_suspencion=''.join(df_suspencion[df_suspencion.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_suspencion.CONTENT_.nunique()
# Out:
# 1240

# %%
PALABRAS_FILTRO = [ 'doble'
                  ]

df_suspencion_= df_suspencion[df_suspencion.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_RPO=df_RPO.drop_duplicates(subset='CONTENT_', keep='first')


df_suspencion_['CONTENT'].count()
# Out:
# 23

# %%
#lematizar
text = texto_suspencion
doc = nlp(text)
lemmas = [tok.lemma_.lower() for tok in doc]

# %%
#pasar de lista a str
texto_suspencion_ = ' '.join([str(elem) for elem in lemmas])

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('HTTPS')
stop_words.append('t')
stop_words.append('ga')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('poder')
stop_words.append('co')
stop_words.append('decir')

sw=set(STOPWORDS)
sw=stop_words

# %%
wc=WordCloud(collocations=True,
             collocation_threshold=30,
            stopwords=sw,
              background_color='white',
              width=1500,
              height=800,
              max_words=80,
             colormap='Dark2',
                    ).generate(texto_suspencion_)

fig, axes = plt.subplots(1, 1, figsize=(20,20), sharex=True, sharey=True)

plt.gca().imshow(wc)
plt.gca().set_title('Topic Global', fontdict=dict(size=16))
plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### 4.3.2. Bigramas

# %%
#bigramas

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
texto_suspencion_big=df_suspencion['CONTENT_'].unique().tolist()
texto_suspencion_big[0]
# Out:
# 'una pregunta para el @grupovanti: si son tan eficientes para verificar la falta de pago de una factura y programar la suspension del servicio, por que no pueden registrar el pago y programar la reconexion?  no es un abuso? @sicsuper @superservicios'

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('https')
stop_words.append('HTTPS')
stop_words.append('CO')
stop_words.append('@')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('natural')
stop_words.append('servicio')
stop_words.append('gas')

# %%
def lemmatize_stemming(text):
    #return stemmer.stem(text)
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    texto_vanti_ = ' '.join([str(elem) for elem in lemmas])
    return texto_vanti_


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_words and len(token) > 2:
            result.append(lemmatize_stemming(token))
           
            #result.append((token))
            
    return result

# %%
processed_docs = []

for doc in texto_suspencion_big:
    processed_docs.append(preprocess(doc))

# %%
processed_docs[0]
# Out:
# ['preguntar',
#  'grupovanti',
#  'tanto',
#  'eficient',
#  'verificar',
#  'falta',
#  'pago',
#  'factura',
#  'programar',
#  'suspension',
#  'poder',
#  'registrar',
#  'pago',
#  'programar',
#  'reconexion',
#  'abuso',
#  'sicsuper',
#  'superservicio']

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in processed_docs]

# View bigrams for the first tweet
terms_bigram[0]
# Out:
# [('preguntar', 'grupovanti'),
#  ('grupovanti', 'tanto'),
#  ('tanto', 'eficient'),
#  ('eficient', 'verificar'),
#  ('verificar', 'falta'),
#  ('falta', 'pago'),
#  ('pago', 'factura'),
#  ('factura', 'programar'),
#  ('programar', 'suspension'),
#  ('suspension', 'poder'),
#  ('poder', 'registrar'),
#  ('registrar', 'pago'),
#  ('pago', 'programar'),
#  ('programar', 'reconexion'),
#  ('reconexion', 'abuso'),
#  ('abuso', 'sicsuper'),
#  ('sicsuper', 'superservicio')]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)
# Out:
# [(('revision', 'periodico'), 66),
#  (('cobrar', 'reconexion'), 58),
#  (('grupovanti', 'cortar'), 52),
#  (('grupovanti', 'superservicio'), 51),
#  (('grupo', 'vanti'), 48),
#  (('venir', 'cortar'), 39),
#  (('senor', 'grupovanti'), 38),
#  (('vanti', 'suspender'), 34),
#  (('visita', 'revision'), 30),
#  (('ir', 'cortar'), 28),
#  (('servicio', 'publico'), 28),
#  (('grupovanti', 'suspender'), 26),
#  (('empresa', 'grupovanti'), 26),
#  (('bogotar', 'boyaca'), 25),
#  (('boyaca', 'cundinamarca'), 25),
#  (('falta', 'pago'), 24),
#  (('hacer', 'revision'), 24),
#  (('llegar', 'recibo'), 24),
#  (('pagar', 'factura'), 23),
#  (('pagar', 'reconexion'), 23)]

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(15),
                             columns=['bigram', 'count'])
bigram_df['bigram']=bigram_df['bigram'].astype(str)
bigram=list((bigram_df['bigram']))
count=list((bigram_df['count']))

# %%
df = bigram_df.iloc[::-1]

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.barh(bigram, count, align='center', alpha=0.5, color='purple')
#plt.yticks(y_pos, )
plt.xlabel('Frecuencia')
plt.title('Frecuencia de bigramas para suspencion')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 4.3.3 n-grams, principales narrativas

# %%
# import necessary libraries

import re, string
from nltk.corpus import stopwords
import nltk

df = df_suspencion.drop_duplicates(subset='CONTENT_', keep='first')
nlp = spacy.load('es_core_news_sm') # español 
def normalize(text):
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    lemmas=" ".join(lemmas)
    doc1 = nlp(lemmas)
    words = [t.orth_ for t in doc1 if not t.is_punct ]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    return lexical_tokens


# list contains  punctuation
sw_list = stopwords.words('spanish')
sw_list += list(string.punctuation)
sw_list = []
sw_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'", '©',
'@', '-', '–','--','—', '_','!!','¡¡','¿','?','!','¡','.co','http ','#','http',':','//']
sw_set = set(sw_list)

# tokenization
def process_data(string):
    tokens = nltk.word_tokenize(string) # tokenization
    punctuation_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    punctuation_removed = [token.lower() for token in tokens ]
    return punctuation_removed

# create a function stemming() and loop through each word in a review
def stemming(string):
    # Stemming
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_string=[]
    for w in string:
        stemmed_string.append(ps.stem(w))
    return stemmed_string


# create a function  and loop through each word in  a review
def lemmatization(string):
    # import libraries
    from nltk.stem.wordnet import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma_list=[]
    for word in string:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Conbime all functions above and obtian cleaned text data 
def data_preprocessing(text_data):
    ##tokenization, stop words removal, punctuation marks removel
    processed_string=list(map(process_data,text_data))
    #stemming
    # stemming_string=list(map(stemming,processed_string)) #Data out prurals 
    ## lemmatization
    lemma_string=list(map(lemmatization,processed_string))
    
    return lemma_string

cleaned_data = data_preprocessing(df['CONTENT'])
merged_data=[]
for i in range(len(cleaned_data )):
    merged_data.append(" ".join(cleaned_data [i]))
merged_df=pd.DataFrame(merged_data)
#merged_df.to_csv("merged_df.csv")

# %%
# obtener los ngrams  
def get_top_n_bigram(corpus, n=None):
    from sklearn.feature_extraction.text import CountVectorizer
    vec = CountVectorizer(ngram_range=(4, 6)).fit(corpus) # minimo y maximo de palabras 
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def bigram_dictionary(data,n=None):
    # n es la cantidad de n_grams que se desean adquirir 
    words_freq=get_top_n_bigram(data,n)
    
    dictionary={}
    for i in range(len(words_freq)):
        dictionary[words_freq[i][0]]=words_freq[i][1]
    return dictionary

BOW = bigram_dictionary(merged_data,15)# get top (merged_data,n= )
BOW

# %%
# Nos quedamos con el BAG que tengan un umbral de similitud de 0.3 (no se parezcan ) 
# y con la frase más larga  
sentences = []
BOW_new = {}
for key0,value0 in BOW.items():
    same = [ key for key,value in BOW.items() if value0==value]
    max_same = max(same)
    same_similarity = [s for s in same if nlp(s).similarity(nlp(max_same))<=0.3] + [max_same] #0.45 Umbral de similitud 
    sentences.append(same_similarity)
    frases = []
    for s in range(len(sentences)):
        lista = list(map(len,sentences[s]))
        try:
            maxi = max(lista)
            frases.append(sentences[s][lista.index(maxi)])
            frases.append(sentences[s][-1])
        except:
            continue 
            
for i in list(dict.fromkeys(frases)):
    BOW_new[i] = BOW[i]

# %%
# from PIL import Image
# twitter_mask = np.array(Image.open('./twitter_mask.png'))
cloud = WordCloud(background_color='white',
                  width=1500,
                  height=800,
                  colormap='tab10',
                  max_words=50,
                  prefer_horizontal=1.0
                 )
                  
plt.figure(figsize=(10,10), facecolor='w')
Wcloud = cloud.generate_from_frequencies(BOW_new, max_font_size=800)
plt.gca().imshow(Wcloud)
plt.gca().set_title('Principales narrativas', fontdict=dict(size=16))
plt.gca().axis('off')
plt.show()

# %% [markdown]
# ### 4.4. Reconexión

# %% [markdown]
# #### 4.4.1. Wordcloud general

# %%
# Contar cant de tweets asociados al filtro

PALABRAS_FILTRO = [ 'recone', 
                  ]

df_reconexion = TABLACONTENT[TABLACONTENT.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_consumo=df_consumo.drop_duplicates(subset='CONTENT_', keep='first')


#filtro por proceso
searchfor=['recone' ]

texto_reconexion=''.join(df_reconexion[df_reconexion.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_reconexion.CONTENT_.nunique()

# %%
#lematizar
text = texto_reconexion
doc = nlp(text)
lemmas = [tok.lemma_.lower() for tok in doc]

# %%
#pasar de lista a str
texto_reconexion_ = ' '.join([str(elem) for elem in lemmas])

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('HTTPS')
stop_words.append('t')
stop_words.append('ga')
stop_words.append('servicio')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('poder')

sw=set(STOPWORDS)
sw=stop_words

# %%
wc=WordCloud(collocations=True,
             collocation_threshold=10,
            stopwords=sw,
              background_color='white',
              width=1500,
              height=800,
              max_words=80,
             colormap='Dark2',
                    ).generate(texto_reconexion_)

fig, axes = plt.subplots(1, 1, figsize=(20,20), sharex=True, sharey=True)

plt.gca().imshow(wc)
plt.gca().set_title('Topic Global', fontdict=dict(size=16))
plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### 4.4.2. Bigramas

# %%
#bigramas

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
texto_reconexion_big=df_reconexion['CONTENT_'].unique().tolist()
texto_reconexion_big[2]

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('https')
stop_words.append('HTTPS')
stop_words.append('CO')
stop_words.append('@')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('natural')

# %%
def lemmatize_stemming(text):
    #return stemmer.stem(text)
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    texto_vanti_ = ' '.join([str(elem) for elem in lemmas])
    return texto_vanti_


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_words and len(token) > 2:
            result.append(lemmatize_stemming(token))
           
            #result.append((token))
            
    return result

# %%
processed_docs = []

for doc in texto_reconexion_big:
    processed_docs.append(preprocess(doc))

# %%
processed_docs[0]

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in processed_docs]

# View bigrams for the first tweet
terms_bigram[0]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(15),
                             columns=['bigram', 'count'])
bigram_df['bigram']=bigram_df['bigram'].astype(str)
bigram=list((bigram_df['bigram']))
count=list((bigram_df['count']))

# %%
df = bigram_df.iloc[::-1]

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.barh(bigram, count, align='center', alpha=0.5, color='purple')
#plt.yticks(y_pos, )
plt.xlabel('Frecuencia')
plt.title('Frecuencia de bigramas para reconexion')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 4.4.3 n-grams, principales narrativas

# %%
# import necessary libraries

import re, string
from nltk.corpus import stopwords
import nltk

df = df_reconexion.drop_duplicates(subset='CONTENT_', keep='first')
nlp = spacy.load('es_core_news_sm') # español 
def normalize(text):
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    lemmas=" ".join(lemmas)
    doc1 = nlp(lemmas)
    words = [t.orth_ for t in doc1 if not t.is_punct ]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    return lexical_tokens


# list contains  punctuation
sw_list = stopwords.words('spanish')
sw_list += list(string.punctuation)
sw_list = []
sw_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'", '©',
'@', '-', '–','--','—', '_','!!','¡¡','¿','?','!','¡','.co','http ','#','http',':','//']
sw_set = set(sw_list)

# tokenization
def process_data(string):
    tokens = nltk.word_tokenize(string) # tokenization
    punctuation_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    punctuation_removed = [token.lower() for token in tokens ]
    return punctuation_removed

# create a function stemming() and loop through each word in a review
def stemming(string):
    # Stemming
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_string=[]
    for w in string:
        stemmed_string.append(ps.stem(w))
    return stemmed_string


# create a function  and loop through each word in  a review
def lemmatization(string):
    # import libraries
    from nltk.stem.wordnet import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma_list=[]
    for word in string:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Conbime all functions above and obtian cleaned text data 
def data_preprocessing(text_data):
    ##tokenization, stop words removal, punctuation marks removel
    processed_string=list(map(process_data,text_data))
    #stemming
    # stemming_string=list(map(stemming,processed_string)) #Data out prurals 
    ## lemmatization
    lemma_string=list(map(lemmatization,processed_string))
    
    return lemma_string

cleaned_data = data_preprocessing(df['CONTENT'])
merged_data=[]
for i in range(len(cleaned_data )):
    merged_data.append(" ".join(cleaned_data [i]))
merged_df=pd.DataFrame(merged_data)
merged_df.to_csv("merged_df.csv")

# %%
# obtener los ngrams  
def get_top_n_bigram(corpus, n=None):
    from sklearn.feature_extraction.text import CountVectorizer
    vec = CountVectorizer(ngram_range=(4, 6)).fit(corpus) # minimo y maximo de palabras 
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def bigram_dictionary(data,n=None):
    # n es la cantidad de n_grams que se desean adquirir 
    words_freq=get_top_n_bigram(data,n)
    
    dictionary={}
    for i in range(len(words_freq)):
        dictionary[words_freq[i][0]]=words_freq[i][1]
    return dictionary

BOW = bigram_dictionary(merged_data,15)# get top (merged_data,n= )
BOW

# %%
# Nos quedamos con el BAG que tengan un umbral de similitud de 0.3 (no se parezcan ) 
# y con la frase más larga  
sentences = []
BOW_new = {}
for key0,value0 in BOW.items():
    same = [ key for key,value in BOW.items() if value0==value]
    max_same = max(same)
    same_similarity = [s for s in same if nlp(s).similarity(nlp(max_same))<=0.4] + [max_same] #0.45 Umbral de similitud 
    sentences.append(same_similarity)
    frases = []
    for s in range(len(sentences)):
        lista = list(map(len,sentences[s]))
        try:
            maxi = max(lista)
            frases.append(sentences[s][lista.index(maxi)])
            frases.append(sentences[s][-1])
        except:
            continue 
            
for i in list(dict.fromkeys(frases)):
    BOW_new[i] = BOW[i]

# %%
# from PIL import Image
# twitter_mask = np.array(Image.open('./twitter_mask.png'))
cloud = WordCloud(background_color='white',
                  width=1500,
                  height=800,
                  colormap='tab10',
                  max_words=60,
                  prefer_horizontal=1.0
                 )
                  
plt.figure(figsize=(10,10), facecolor='w')
Wcloud = cloud.generate_from_frequencies(BOW_new, max_font_size=800)
plt.gca().imshow(Wcloud)
plt.gca().set_title('Principales narrativas', fontdict=dict(size=16))
plt.gca().axis('off')
plt.show()

# %% [markdown]
# ### 4.5. Factura

# %% [markdown]
# #### 4.5.1. Wordcloud general

# %%
# Contar cant de tweets asociados al filtro

PALABRAS_FILTRO = [ 'factur', 
                  ]

df_factura = TABLACONTENT[TABLACONTENT.CONTENT_.apply(lambda x: any(y in x for y in PALABRAS_FILTRO))]
#df_consumo=df_consumo.drop_duplicates(subset='CONTENT_', keep='first')


#filtro por proceso
searchfor=['factur' ]

texto_factura=''.join(df_factura[df_factura.CONTENT_.str.contains('|'.join(searchfor))].fillna('')['CONTENT_'].tolist())
df_factura.CONTENT_.nunique()

# %%
#lematizar
text = texto_factura
doc = nlp(text)
lemmas = [tok.lemma_.lower() for tok in doc]

# %%
#pasar de lista a str
texto_factura_ = ' '.join([str(elem) for elem in lemmas])

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('HTTPS')
stop_words.append('t')
stop_words.append('ga')
stop_words.append('servicio')
stop_words.append('tener')
stop_words.append('hacer')
stop_words.append('haber')
stop_words.append('poder')
stop_words.append('ma')

sw=set(STOPWORDS)
sw=stop_words

# %%
wc=WordCloud(collocations=True,
             collocation_threshold=10,
            stopwords=sw,
              background_color='white',
              width=1500,
              height=800,
              max_words=80,
             colormap='Dark2',
                    ).generate(texto_factura_)

fig, axes = plt.subplots(1, 1, figsize=(20,20), sharex=True, sharey=True)

plt.gca().imshow(wc)
plt.gca().set_title('Topic Global', fontdict=dict(size=16))
plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### 4.5.2. Bigramas

# %%
#bigramas

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx

import warnings
warnings.filterwarnings("ignore")

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

# %%
texto_factura_big=df_factura['CONTENT_'].unique().tolist()
texto_factura_big[2]

# %%
#Definir stopwords
from stop_words import get_stop_words
stop_words=get_stop_words('spanish')
stop_words.append('HTTP')
stop_words.append('https')
stop_words.append('HTTPS')
stop_words.append('CO')
stop_words.append('@')
stop_words.append('hacer')
stop_words.append('tener')
stop_words.append('ser')
stop_words.append('haber')
stop_words.append('natural')

# %%
def lemmatize_stemming(text):
    #return stemmer.stem(text)
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    texto_vanti_ = ' '.join([str(elem) for elem in lemmas])
    return texto_vanti_


# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in stop_words and len(token) > 2:
            result.append(lemmatize_stemming(token))
           
            #result.append((token))
            
    return result

# %%
processed_docs = []

for doc in texto_factura_big:
    processed_docs.append(preprocess(doc))

# %%
processed_docs[2]

# %%
# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in processed_docs]

# View bigrams for the first tweet
terms_bigram[2]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(15),
                             columns=['bigram', 'count'])
bigram_df['bigram']=bigram_df['bigram'].astype(str)
bigram=list((bigram_df['bigram']))
count=list((bigram_df['count']))

# %%
df = bigram_df.iloc[::-1]

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


plt.barh(bigram, count, align='center', alpha=0.5, color='purple')
#plt.yticks(y_pos, )
plt.xlabel('Frecuencia')
plt.title('Frecuencia de bigramas para factura')
#plt.axis('off')
plt.show()

# %% [markdown]
# #### 4.5.3 n-grams, principales narrativas

# %%
# import necessary libraries

import re, string
from nltk.corpus import stopwords
import nltk

df = df_factura
#.drop_duplicates(subset='CONTENT_', keep='first')
nlp = spacy.load('es_core_news_sm') # español 
def normalize(text):
    doc = nlp(text)
    lemmas = [tok.lemma_.lower() for tok in doc]
    lemmas=" ".join(lemmas)
    doc1 = nlp(lemmas)
    words = [t.orth_ for t in doc1 if not t.is_punct ]
    lexical_tokens = [t.lower() for t in words if len(t) > 3 and t.isalpha()]
    return lexical_tokens


# list contains  punctuation
sw_list = stopwords.words('spanish')
sw_list += list(string.punctuation)
sw_list = []
sw_list += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘',"'", '©',
'@', '-', '–','--','—', '_','!!','¡¡','¿','?','!','¡','.co','http ','#','http',':','//']
sw_set = set(sw_list)

# tokenization
def process_data(string):
    tokens = nltk.word_tokenize(string) # tokenization
    punctuation_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    punctuation_removed = [token.lower() for token in tokens ]
    return punctuation_removed

# create a function stemming() and loop through each word in a review
def stemming(string):
    # Stemming
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    stemmed_string=[]
    for w in string:
        stemmed_string.append(ps.stem(w))
    return stemmed_string


# create a function  and loop through each word in  a review
def lemmatization(string):
    # import libraries
    from nltk.stem.wordnet import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    lemma_list=[]
    for word in string:
        lemma_word=lemmatizer.lemmatize(word,pos='v') 
        lemma_list.append(lemma_word)
    return lemma_list

# Conbime all functions above and obtian cleaned text data 
def data_preprocessing(text_data):
    ##tokenization, stop words removal, punctuation marks removel
    processed_string=list(map(process_data,text_data))
    #stemming
    # stemming_string=list(map(stemming,processed_string)) #Data out prurals 
    ## lemmatization
    lemma_string=list(map(lemmatization,processed_string))
    
    return lemma_string

cleaned_data = data_preprocessing(df['CONTENT'])
merged_data=[]
for i in range(len(cleaned_data )):
    merged_data.append(" ".join(cleaned_data [i]))
merged_df=pd.DataFrame(merged_data)
merged_df.to_csv("merged_df.csv")

# %%
# obtener los ngrams  
def get_top_n_bigram(corpus, n=None):
    from sklearn.feature_extraction.text import CountVectorizer
    vec = CountVectorizer(ngram_range=(4, 6)).fit(corpus) # minimo y maximo de palabras 
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

def bigram_dictionary(data,n=None):
    # n es la cantidad de n_grams que se desean adquirir 
    words_freq=get_top_n_bigram(data,n)
    
    dictionary={}
    for i in range(len(words_freq)):
        dictionary[words_freq[i][0]]=words_freq[i][1]
    return dictionary

BOW = bigram_dictionary(merged_data,15)# get top (merged_data,n= )
BOW

# %%
# Nos quedamos con el BAG que tengan un umbral de similitud de 0.3 (no se parezcan ) 
# y con la frase más larga  
sentences = []
BOW_new = {}
for key0,value0 in BOW.items():
    same = [ key for key,value in BOW.items() if value0==value]
    max_same = max(same)
    same_similarity = [s for s in same if nlp(s).similarity(nlp(max_same))<=0.4] + [max_same] #0.45 Umbral de similitud 
    sentences.append(same_similarity)
    frases = []
    for s in range(len(sentences)):
        lista = list(map(len,sentences[s]))
        try:
            maxi = max(lista)
            frases.append(sentences[s][lista.index(maxi)])
            frases.append(sentences[s][-1])
        except:
            continue 
            
for i in list(dict.fromkeys(frases)):
    BOW_new[i] = BOW[i]

# %%
# from PIL import Image
# twitter_mask = np.array(Image.open('./twitter_mask.png'))
cloud = WordCloud(background_color='white',
                  width=1500,
                  height=800,
                  colormap='tab10',
                  max_words=60,
                  prefer_horizontal=1.0
                 )
                  
plt.figure(figsize=(10,10), facecolor='w')
Wcloud = cloud.generate_from_frequencies(BOW_new, max_font_size=800)
plt.gca().imshow(Wcloud)
plt.gca().set_title('Principales narrativas', fontdict=dict(size=16))
plt.gca().axis('off')
plt.show()
